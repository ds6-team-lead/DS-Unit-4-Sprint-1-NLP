# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# # Natural Language Processing (NLP)
# ## EDC *Data Science Unit 4 Sprint 1 Assignment 1*
#
# Your goal in assignment: find the attributes of the best & worst coffee shops in the dataset. The text is fairly raw: dates in the review, extra words in the `star_rating` column, etc. You'll probably want to clean that stuff up for a better analysis.
#
# Analyze the corpus of text using text visualizations of token frequency. Try cleaning the data as much as possible. Try the following techniques:
# - Lemmatization
# - Custom stopword removal
#
# Keep in mind the attributes of good tokens. Once you have a solid baseline, layer in the star rating in your visualization(s). Keep part in this assignment - produce a write-up of the attributes of the best and worst coffee shops. Based on your analysis, what makes the best the best and the worst the worst. Use graphs and numbesr from your analysis to support your conclusions. There should be plenty of markdown cells! :coffee:

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('Jml7NVYm8cs')

# %%
#   !pip install spacy squarify
# Out:
# Requirement already satisfied: spacy in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (2.1.8)
# Requirement already satisfied: squarify in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (0.4.3)
# Requirement already satisfied: srsly<1.1.0,>=0.0.6 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from spacy) (0.1.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from spacy) (2.21.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from spacy) (0.9.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from spacy) (2.0.2)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from spacy) (2.0.1)
# Requirement already satisfied: blis<0.3.0,>=0.2.2 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from spacy) (0.2.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from spacy) (0.2.2)
# Requirement already satisfied: thinc<7.1.0,>=7.0.8 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from spacy) (7.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from spacy) (1.16.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from spacy) (1.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from thinc<7.1.0,>=7.0.8->spacy) (4.31.1)

# %%
import pandas as pd
 
shops = pd.read_csv('./data/yelp_coffeeshop_review_data.csv')
shops.head()
# Out:
#                   coffee_shop_name  \
# 0  The Factory - Cafe With a Soul
# 1  The Factory - Cafe With a Soul
# 2  The Factory - Cafe With a Soul
# 3  The Factory - Cafe With a Soul
# 4  The Factory - Cafe With a Soul
#
#                                     full_review_text        star_rating
# 0   11/25/2016 1 check-in Love love loved the atm...   5.0 star rating
# 1   12/2/2016 Listed in Date Night: Austin, Ambia...   4.0 star rating
# 2   11/30/2016 1 check-in Listed in Brunch Spots ...   4.0 star rating
# 3   11/25/2016 Very cool decor! Good drinks Nice ...   2.0 star rating
# 4   12/3/2016 1 check-in They are located within ...   4.0 star rating

# %%
# Start here 
df = shops
df['rating'] = df['star_rating'].apply(lambda x: x.replace(' star rating', '')).astype('float')
df['date'] = df['full_review_text'].apply(lambda x: x.split()[0])
df['full_review_text'] = shops['full_review_text'].apply(lambda x: " ".join(x.split()[1:]))
del df['star_rating']
df.head()
# Out:
#                   coffee_shop_name  \
# 0  The Factory - Cafe With a Soul
# 1  The Factory - Cafe With a Soul
# 2  The Factory - Cafe With a Soul
# 3  The Factory - Cafe With a Soul
# 4  The Factory - Cafe With a Soul
#
#                                     full_review_text  rating        date
# 0  1 check-in Love love loved the atmosphere! Eve...     5.0  11/25/2016
# 1  Listed in Date Night: Austin, Ambiance in Aust...     4.0   12/2/2016
# 2  1 check-in Listed in Brunch Spots I loved the ...     4.0  11/30/2016
# 3  Very cool decor! Good drinks Nice seating Howe...     2.0  11/25/2016
# 4  1 check-in They are located within the Northcr...     4.0   12/3/2016

# %%
import spacy

nlp = spacy.load('en_core_web_lg')

# %%
def get_lemmas(text):
    lemmas = []
    
    doc = nlp(text)
    
    for token in doc:
        if ((token.is_stop == False) and (token.is_punct == False)) and (token.pos!= 'PRON'):
            lemmas.append(token.lemma_)
            
    return lemmas

# %%
df['tokens'] = df['full_review_text'].apply(get_lemmas)

# %%
from collections import Counter

def count(docs):

        word_counts = Counter()
        appears_in = Counter()
        
        total_docs = len(docs)

        for doc in docs:
            word_counts.update(doc)
            appears_in.update(set(doc))

        temp = zip(word_counts.keys(), word_counts.values())
        
        wc = pd.DataFrame(temp, columns = ['word', 'count'])

        wc['rank'] = wc['count'].rank(method='first', ascending=False)
        total = wc['count'].sum()

        wc['pct_total'] = wc['count'].apply(lambda x: x / total)
        
        wc = wc.sort_values(by='rank')
        wc['cul_pct_total'] = wc['pct_total'].cumsum()

        t2 = zip(appears_in.keys(), appears_in.values())
        ac = pd.DataFrame(t2, columns=['word', 'appears_in'])
        wc = ac.merge(wc, on='word')

        wc['appears_in_pct'] = wc['appears_in'].apply(lambda x: x / total_docs)
        
        return wc.sort_values(by='rank')

# %% [markdown]
# # How do we want to analyse these coffee shop tokens?
#  - Overall Word/Token Count
#  - View Counts by Rating

# %%
wc = count(shops['tokens'])

# %%
wc.head()
# Out:
#        word  appears_in  count  rank  pct_total  cul_pct_total  appears_in_pct
# 11   coffee        4848  10153   1.0   0.028057       0.028057        0.636555
# 115   place        3879   6026   2.0   0.016652       0.044709        0.509322
# 163    good        3590   5393   3.0   0.014903       0.059612        0.471376
# 63    great        2843   3924   4.0   0.010844       0.070456        0.373293
# 2     check        3175   3467   5.0   0.009581       0.080037        0.416886

# %%
import squarify
import matplotlib.pyplot as plt

# This is showing Overall Word Counts
wc_top20 = wc[wc['rank'] <= 20]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8)
plt.axis('off')
plt.show()

# %%
shops['coffee_shop_name'].nunique()
# Out:
# 79

# %%
# Lets look at Bad Coffee Shops

# What is a 'bad' coffee shop?
import seaborn as sns

sns.distplot(shops['rating'])

# %%
# A bad coffee shop has a rating of between 1 and 3 based on the distribution of ratings.

# %%
wc_bad = count(shops[shops['rating'] <4]['tokens'])

# %%
wc_top20_bad = wc_bad[wc_bad['rank'] <= 20]

squarify.plot(sizes=wc_top20_bad['pct_total'], label=wc_top20_bad['word'], alpha=.8)
plt.axis('off')
plt.show()

# %%
wc_good = count(shops[shops['rating'] >= 4]['tokens'])

# %%
wc_top20_good = wc_good[wc_good['rank'] <= 20]

squarify.plot(sizes=wc_top20_good['pct_total'], label=wc_top20_good['word'], alpha=.8)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Can Visualize the words with the greatest difference in counts between 'good' and 'bad'?
#
# Couple Notes:
#
# - Relative frequency of absolute counts because of different # of reviews
# - only look at the top 5-10 words with the greatest differences

# %%
wc_bad['appears_in_pct_bad'] = wc_bad['appears_in_pct']
diff = wc_good[['word', 'appears_in_pct']].merge(wc_bad[['word', 'appears_in_pct_bad']], how='outer')

# %%
diff.head()
# Out:
#      word  appears_in_pct  appears_in_pct_bad
# 0  coffee        0.637785            0.631436
# 1   place        0.508958            0.510840
# 2    good        0.480130            0.434959
# 3   great        0.406678            0.234417
# 4   check        0.437459            0.331301

# %%
diff['diff'] = diff['appears_in_pct'] - diff['appears_in_pct_bad']
diff.head()
# Out:
#      word  appears_in_pct  appears_in_pct_bad      diff
# 0  coffee        0.637785            0.631436  0.006349
# 1   place        0.508958            0.510840 -0.001882
# 2    good        0.480130            0.434959  0.045171
# 3   great        0.406678            0.234417  0.172260
# 4   check        0.437459            0.331301  0.106158

# %%
diff.sort_values(by='diff')
# Out:
#                   word  appears_in_pct  appears_in_pct_bad      diff
# 5                 like        0.273127            0.403794 -0.130667
# 19               order        0.166287            0.292005 -0.125719
# 139                ask        0.050651            0.149051 -0.098400
# 36             service        0.138274            0.234417 -0.096144
# 209                bad        0.036645            0.128726 -0.092081
# 26                  go        0.140228            0.228320 -0.088092
# 49               taste        0.106026            0.189702 -0.083676
# 87                   $        0.064169            0.147696 -0.083527
# 161           customer        0.044788            0.126016 -0.081228
# 150                say        0.047231            0.126016 -0.078785
# 99              review        0.074593            0.151084 -0.076491
# 248              maybe        0.030945            0.105014 -0.074069
# 44               think        0.107166            0.177507 -0.070341
# 396                 ok        0.019218            0.089431 -0.070213
# 7                 come        0.241205            0.306233 -0.065028
# 10                time        0.218893            0.283875 -0.064983
# 42                want        0.120033            0.184959 -0.064927
# 125               star        0.055863            0.119919 -0.064056
# 124               take        0.059121            0.122629 -0.063508
# 1739              rude        0.003094            0.065718 -0.062624
# 30              pretty        0.129805            0.191734 -0.061930
# 321                pay        0.023127            0.084688 -0.061561
# 230             minute        0.033062            0.092818 -0.059757
# 140         experience        0.052769            0.110434 -0.057665
# 132               well        0.056840            0.114499 -0.057658
# 93                wait        0.069218            0.124661 -0.055443
# 386               will        0.018893            0.073171 -0.054278
# 43                look        0.118078            0.170732 -0.052654
# 176               tell        0.041531            0.092818 -0.051287
# 27              people        0.140554            0.190379 -0.049826
# ...                ...             ...                 ...       ...
# 16861         imposing             NaN            0.000678       NaN
# 16862         4.95/jug             NaN            0.000678       NaN
# 16863          flowery             NaN            0.000678       NaN
# 16864        ~$2.50-$3             NaN            0.000678       NaN
# 16865           strada             NaN            0.000678       NaN
# 16866            sneer             NaN            0.000678       NaN
# 16867  unintentionally             NaN            0.000678       NaN
# 16868          damaged             NaN            0.000678       NaN
# 16869         amputate             NaN            0.000678       NaN
# 16870            1,000             NaN            0.000678       NaN
# 16871        reimburse             NaN            0.000678       NaN
# 16872        insurance             NaN            0.000678       NaN
# 16873      drastically             NaN            0.000678       NaN
# 16874           Modena             NaN            0.000678       NaN
# 16875              sou             NaN            0.000678       NaN
# 16876             vide             NaN            0.000678       NaN
# 16877             wilt             NaN            0.000678       NaN
# 16878         gazpacho             NaN            0.000678       NaN
# 16879         clincher             NaN            0.000678       NaN
# 16880         conveyor             NaN            0.000678       NaN
# 16881      overzealous             NaN            0.000678       NaN
# 16882          realise             NaN            0.000678       NaN
# 16883    prohibitively             NaN            0.000678       NaN
# 16884         migraine             NaN            0.000678       NaN
# 16885           GLUTEN             NaN            0.000678       NaN
# 16886             Ravi             NaN            0.000678       NaN
# 16887       uneventful             NaN            0.000678       NaN
# 16888             nora             NaN            0.000678       NaN
# 16889            fried             NaN            0.000678       NaN
# 16890           tasted             NaN            0.000678       NaN
#
# [16891 rows x 4 columns]

# %%
count(shops['tokens']).sort_values('count', ascending=False)
# Out:
#                   word  appears_in  count     rank  pct_total  cul_pct_total  \
# 11              coffee        4848  10153      1.0   0.028057       0.028057
# 115              place        3879   6026      2.0   0.016652       0.044709
# 163               good        3590   5393      3.0   0.014903       0.059612
# 63               great        2843   3924      4.0   0.010844       0.070456
# 2                check        3175   3467      5.0   0.009581       0.080037
# 155               like        2273   3379      6.0   0.009338       0.089374
# 389               come        1933   2639      7.0   0.007293       0.096667
# 483               time        1763   2382      8.0   0.006582       0.103249
# 16               drink        1638   2343      9.0   0.006475       0.109724
# 32                love        1799   2339     10.0   0.006464       0.116187
# 46              Austin        1785   2274     11.0   0.006284       0.122471
# 38                   1        2143   2248     12.0   0.006212       0.128684
# 36                shop        1630   2185     13.0   0.006038       0.134722
# 30               order        1452   2146     14.0   0.005930       0.140652
# 139                try        1671   2139     15.0   0.005911       0.146563
# 643               work        1492   1923     16.0   0.005314       0.151877
# 28                 get        1482   1919     17.0   0.005303       0.157180
# 334               food        1400   1890     18.0   0.005223       0.162403
# 55                nice        1502   1793     19.0   0.004955       0.167358
# 186           friendly        1627   1723     20.0   0.004761       0.172119
# 21               latte        1145   1645     21.0   0.004546       0.176665
# 602             little        1235   1496     22.0   0.004134       0.180799
# 41                  go        1198   1481     23.0   0.004093       0.184891
# 469             people        1144   1402     24.0   0.003874       0.188766
# 740          delicious        1241   1373     25.0   0.003794       0.192560
# 10              pretty        1080   1366     26.0   0.003775       0.196335
# 154            service        1195   1366     27.0   0.003775       0.200109
# 482                tea         762   1343     28.0   0.003711       0.203821
# 98                 lot        1111   1324     29.0   0.003659       0.207479
# 419              staff        1188   1282     30.0   0.003543       0.211022
# ...                ...         ...    ...      ...        ...            ...
# 9448         handcraft           1      1  11817.0   0.000003       0.985978
# 9457             flesh           1      1  11818.0   0.000003       0.985981
# 9460           Yuvaraj           1      1  11819.0   0.000003       0.985984
# 9463                V.           1      1  11820.0   0.000003       0.985987
# 9504            custer           1      1  11845.0   0.000003       0.986056
# 9495              Opal           1      1  11844.0   0.000003       0.986053
# 9494           cassata           1      1  11843.0   0.000003       0.986050
# 9497           rightly           1      1  11842.0   0.000003       0.986048
# 9503        powerhouse           1      1  11841.0   0.000003       0.986045
# 9501          Latteria           1      1  11840.0   0.000003       0.986042
# 9491              lite           1      1  11839.0   0.000003       0.986039
# 9490          flavors-           1      1  11838.0   0.000003       0.986036
# 9484             nooby           1      1  11837.0   0.000003       0.986034
# 9487              noob           1      1  11836.0   0.000003       0.986031
# 9485          novetaly           1      1  11835.0   0.000003       0.986028
# 9486      AAAMPLLLLESS           1      1  11834.0   0.000003       0.986025
# 9483             SAAAA           1      1  11833.0   0.000003       0.986023
# 9489              clip           1      1  11832.0   0.000003       0.986020
# 9480              FOMO           1      1  11831.0   0.000003       0.986017
# 9479   adventurousness           1      1  11830.0   0.000003       0.986014
# 9472           romance           1      1  11829.0   0.000003       0.986012
# 9471          rekindle           1      1  11828.0   0.000003       0.986009
# 9473        invitation           1      1  11827.0   0.000003       0.986006
# 9475          nightcap           1      1  11826.0   0.000003       0.986003
# 9476            Sample           1      1  11825.0   0.000003       0.986001
# 9469             Quyen           1      1  11824.0   0.000003       0.985998
# 9466           Medium-           1      1  11823.0   0.000003       0.985995
# 9468          misspell           1      1  11822.0   0.000003       0.985992
# 9467        displayed-           1      1  11821.0   0.000003       0.985990
# 16889        digestion           1      1  16891.0   0.000003       1.000000
#
#        appears_in_pct
# 11           0.636555
# 115          0.509322
# 163          0.471376
# 63           0.373293
# 2            0.416886
# 155          0.298451
# 389          0.253808
# 483          0.231486
# 16           0.215074
# 32           0.236213
# 46           0.234375
# 38           0.281381
# 36           0.214023
# 30           0.190651
# 139          0.219407
# 643          0.195903
# 28           0.194590
# 334          0.183824
# 55           0.197216
# 186          0.213629
# 21           0.150341
# 602          0.162159
# 41           0.157300
# 469          0.150210
# 740          0.162946
# 10           0.141807
# 154          0.156907
# 482          0.100053
# 98           0.145877
# 419          0.155987
# ...               ...
# 9448         0.000131
# 9457         0.000131
# 9460         0.000131
# 9463         0.000131
# 9504         0.000131
# 9495         0.000131
# 9494         0.000131
# 9497         0.000131
# 9503         0.000131
# 9501         0.000131
# 9491         0.000131
# 9490         0.000131
# 9484         0.000131
# 9487         0.000131
# 9485         0.000131
# 9486         0.000131
# 9483         0.000131
# 9489         0.000131
# 9480         0.000131
# 9479         0.000131
# 9472         0.000131
# 9471         0.000131
# 9473         0.000131
# 9475         0.000131
# 9476         0.000131
# 9469         0.000131
# 9466         0.000131
# 9468         0.000131
# 9467         0.000131
# 16889        0.000131
#
# [16891 rows x 7 columns]

# %% [markdown]
# ## Stretch Goals
#
# * Analyze another corpus of documents - such as Indeed.com job listings ;).
# * Play the the Spacy API to
#  - Extract Named Entities
#  - Extracting 'noun chunks'
#  - Attempt Document Classification with just Spacy
#  - *Note:* This [course](https://course.spacy.io/) will be of interesting in helping you with these stretch goals.
# * Try to build a plotly dash app with your text data

# %%
dir(nlp)
# Out:
# ['Defaults',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_meta',
#  '_optimizer',
#  '_path',
#  'add_pipe',
#  'begin_training',
#  'create_pipe',
#  'disable_pipes',
#  'entity',
#  'evaluate',
#  'factories',
#  'from_bytes',
#  'from_disk',
#  'get_pipe',
#  'has_pipe',
#  'lang',
#  'linker',
#  'make_doc',
#  'matcher',
#  'max_length',
#  'meta',
#  'parser',
#  'path',
#  'pipe',
#  'pipe_names',
#  'pipeline',
#  'preprocess_gold',
#  'rehearse',
#  'remove_pipe',
#  'rename_pipe',
#  'replace_pipe',
#  'resume_training',
#  'tagger',
#  'tensorizer',
#  'to_bytes',
#  'to_disk',
#  'tokenizer',
#  'update',
#  'use_params',
#  'vocab']

# %%
# Extracting Named Entities
from spacy import extract_entity
spacy_extract_entity()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-45-a9bc98dcbffe> in <module>
#       1 # Extracting Named Entities
# ----> 2 from spacy import extract_entity
#       3 spacy_extract_entity()
#
# ImportError: cannot import name 'extract_entity' from 'spacy' (/Users/Inceptive/anaconda3/lib/python3.7/site-packages/spacy/__init__.py)

# %%
# Extracting Noun Chunks

# %%
# Attempt Document Classification with just Spacy

# %%
# !pip install gensim
from gensim.models import Word2Vec, KeyedVectors
import pandas 
import nltk
# Out:
# Requirement already satisfied: gensim in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (3.8.1)
# Requirement already satisfied: six>=1.5.0 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from gensim) (1.12.0)
# Requirement already satisfied: scipy>=0.18.1 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from gensim) (1.2.1)
# Requirement already satisfied: numpy>=1.11.3 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from gensim) (1.16.2)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from gensim) (1.8.4)
# Requirement already satisfied: requests in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim) (2.21.0)
# Requirement already satisfied: boto3 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim) (1.9.238)
# Requirement already satisfied: boto>=2.32 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (2019.6.16)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim) (2.8)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from boto3->smart-open>=1.8.1->gensim) (0.9.4)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from boto3->smart-open>=1.8.1->gensim) (0.2.1)
# Requirement already satisfied: botocore<1.13.0,>=1.12.238 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from boto3->smart-open>=1.8.1->gensim) (1.12.238)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from botocore<1.13.0,>=1.12.238->boto3->smart-open>=1.8.1->gensim) (2.8.0)
# Requirement already satisfied: docutils<0.16,>=0.10 in /Users/Inceptive/anaconda3/lib/python3.7/site-packages (from botocore<1.13.0,>=1.12.238->boto3->smart-open>=1.8.1->gensim) (0.14)

# %%
texts = df['full_review_text'].values

# %%
texts
# Out:
# array(['1 check-in Love love loved the atmosphere! Every corner of the coffee shop had its own style, and there were swings!!! I ordered the matcha latte, and it was muy fantastico! Ordering and getting my drink were pretty streamlined. I ordered on an iPad, which included all beverage selections that ranged from coffee to wine, desired level of sweetness, and a checkout system. I got my latte within minutes! I was hoping for a typical heart or feather on my latte, but found myself listing out all the possibilities of what the art may be. Any ideas?',
#        'Listed in Date Night: Austin, Ambiance in Austin BEAUTIFUL!!!! Love the ambiance! Instagram-worthy!!! Definitely $$$, so be prepared. This is gonna cost you a pretty penny :) Waffle dessert was just decent...nothing to rave about. But, will probably be back just to be somewhere unique and nice.',
#        "1 check-in Listed in Brunch Spots I loved the eclectic and homey plush decor and who doesn't want to swing and drink their coffee? I would categorize this as a pricier coffee place but, to me it was worth it. After Thanksgiving nobody wants to make brunch so we headed out in search of chicken and waffles. There is ample parking in the private lot and ordering is done through I-Pads. Pick a seat and they will call your name when your items are ready. Be patient because some of the coffee drinks take longer than others. I had the cold brew coffee, chicken and waffles and we shared a pop+art! The po+art was strawberry; light and fluffy on the outside and gooey sweet filling on the inside. The chicken and waffles wasn't the standard so expect different, complex and interesting flavors from the accompanying slaw and sauce. I thoroughly enjoyed it but, the waffle was a bit bland and maybe could have used a bit of honey to spruce it up. The coffee here is spot on and I hear that their hot chocolate is the bomb but, I will have to wait for the weather to cool off to try that. A great place to be cozy and chat with your friends, a date or read a book. Chicken and waffles Pop tart Coffee See all photos from Carmela S. for The Factory - Cafe With a Soul",
#        ...,
#        'Loved coming here for tea, and the atmosphere was pretty and fresh. I ordered the strawberry herbal tea, and my friend had the scone and eggs.',
#        "The food is just average. The booths didn't feel very clean. The waitstaff was friendly and fairly efficient though. I went with a tea enthusiast family member and they seemed impressed with the teas and things here. I probably wouldn't go back or recommend this place.",
#        "I finally stopped in for lunch with my colleague and I'm so glad we did. I had a delicious coconut milk soup and a chai tea. Yum!"],
#       dtype=object)

# %%
textVec = [nltk.word_tokenize(text) for text in texts]

# %%
model = Word2Vec(textVec, min_count=1, size=32)

# %%
model.most_similar('Good')
# Out:
# /Users/Inceptive/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('Great', 0.9224764108657837),
#  ('Nice', 0.9031819105148315),
#  ('Excellent', 0.8557831048965454),
#  ('Friendly', 0.8486466407775879),
#  ('Clean', 0.8042943477630615),
#  ('Teas', 0.7987236976623535),
#  ('laidback', 0.7966307401657104),
#  ('Awesome', 0.7842494249343872),
#  ('Fast', 0.7833265066146851),
#  ('Cool', 0.7787601947784424)]

# %%
model.cum_table
# Out:
# /Users/Inceptive/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `cum_table` (Attribute will be removed in 4.0.0, use self.vocabulary.cum_table instead).
#   """Entry point for launching an IPython kernel.
# array([  36501242,   62510040,   87179899, ..., 2147460799, 2147472223,
#        2147483647], dtype=uint32)

# %%
dir(model)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adapt_by_suffix',
#  '_check_input_data_sanity',
#  '_check_training_sanity',
#  '_clear_post_train',
#  '_do_train_epoch',
#  '_do_train_job',
#  '_get_job_params',
#  '_get_thread_working_mem',
#  '_job_producer',
#  '_load_specials',
#  '_log_epoch_end',
#  '_log_epoch_progress',
#  '_log_progress',
#  '_log_train_end',
#  '_minimize_model',
#  '_raw_word_count',
#  '_save_specials',
#  '_set_train_params',
#  '_smart_save',
#  '_train_epoch',
#  '_train_epoch_corpusfile',
#  '_update_job_params',
#  '_worker_loop',
#  '_worker_loop_corpusfile',
#  'accuracy',
#  'alpha',
#  'batch_words',
#  'build_vocab',
#  'build_vocab_from_freq',
#  'callbacks',
#  'cbow_mean',
#  'clear_sims',
#  'compute_loss',
#  'corpus_count',
#  'corpus_total_words',
#  'cum_table',
#  'delete_temporary_training_data',
#  'doesnt_match',
#  'epochs',
#  'estimate_memory',
#  'evaluate_word_pairs',
#  'get_latest_training_loss',
#  'hashfxn',
#  'hs',
#  'init_sims',
#  'intersect_word2vec_format',
#  'iter',
#  'layer1_size',
#  'load',
#  'load_word2vec_format',
#  'log_accuracy',
#  'max_final_vocab',
#  'min_alpha',
#  'min_alpha_yet_reached',
#  'min_count',
#  'model_trimmed_post_training',
#  'most_similar',
#  'most_similar_cosmul',
#  'n_similarity',
#  'negative',
#  'ns_exponent',
#  'predict_output_word',
#  'random',
#  'reset_from',
#  'running_training_loss',
#  'sample',
#  'save',
#  'save_word2vec_format',
#  'score',
#  'sg',
#  'similar_by_vector',
#  'similar_by_word',
#  'similarity',
#  'syn0_lockf',
#  'syn1',
#  'syn1neg',
#  'total_train_time',
#  'train',
#  'train_count',
#  'trainables',
#  'vector_size',
#  'vocabulary',
#  'window',
#  'wmdistance',
#  'workers',
#  'wv']

# %%
# pretend TL is an owner

# we are to bring a presentation of recommendations with charts and graphs 
# recommending what they should do to improve sales, product, their shop etc
# VALUABLE SKILLS 

shops.head()
# Out:
#                   coffee_shop_name  \
# 0  The Factory - Cafe With a Soul
# 1  The Factory - Cafe With a Soul
# 2  The Factory - Cafe With a Soul
# 3  The Factory - Cafe With a Soul
# 4  The Factory - Cafe With a Soul
#
#                                     full_review_text        star_rating
# 0   11/25/2016 1 check-in Love love loved the atm...   5.0 star rating
# 1   12/2/2016 Listed in Date Night: Austin, Ambia...   4.0 star rating
# 2   11/30/2016 1 check-in Listed in Brunch Spots ...   4.0 star rating
# 3   11/25/2016 Very cool decor! Good drinks Nice ...   2.0 star rating
# 4   12/3/2016 1 check-in They are located within ...   4.0 star rating

# %%
# Getting all the 'Genuine Joe' observations for our TL groups presentations
shops = shops[shops['coffee_shop_name'].str.contains('Genuine')]

# %%
# Cleaning up the data to be more useable for our purposes 
df = shops
df['rating'] = df['star_rating'].apply(lambda x: x.replace(' star rating', '')).astype('float')
df['date'] = df['full_review_text'].apply(lambda x: x.split()[0])
df['full_review_text'] = shops['full_review_text'].apply(lambda x: " ".join(x.split()[1:]))
df['full_review_text'] = df['full_review_text'].map(lambda x: x.lower())
del df['star_rating']

df.head()
# Out:
#      coffee_shop_name                                   full_review_text  \
# 5241     Genuine Joe   seriously the best iced chai in austin. i am n...
# 5242     Genuine Joe   room nice. plain coffee meh. they have intrigu...
# 5243     Genuine Joe   1 check-in the artist group i belong to had a ...
# 5244     Genuine Joe   1 check-in i came here because it was the high...
# 5245     Genuine Joe   hands down my favorite coffee shop in austin. ...
#
#       rating        date
# 5241     5.0  11/27/2016
# 5242     4.0   11/6/2016
# 5243     4.0   8/25/2016
# 5244     4.0    6/9/2016
# 5245     5.0  11/23/2016

# %%
# Getting the NLP locked and loaded
import spacy
nlp = spacy.load('en_core_web_lg')

# %%
nlp.Defaults.stop_words.add('coffee')

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'nine', 'eight', 'is', 'full', 'except', 'please', 'either', 'empty', 'will', 'along', 'than', 'be', 'anyhow', 'something', 'still', 'ours', 'serious', 'same', 'very', 'have', ' coffee ', '’re', 'to', 'anyone', 'himself', 'they', '‘re', 'ourselves', 'whom', 'hereupon', 'noone', 'austin', 'former', 'sometime', 'again', 'afterwards', 'until', 'n‘t', 'became', 'mostly', 'with', 'meanwhile', 'go', 'as', '‘ll', 'regarding', 'can', 'otherwise', 'and', 'these', "'s", 'whether', 'does', 'back', 'unless', 'below', 'why', 'therein', 'her', 'every', 'though', 'shop', 'had', 'almost', 'anything', "'ll", 'in', 'five', 'yet', 'thereupon', 'thereafter', 'seemed', 'so', 'really', "'d", 'us', '’s', 'thereby', 'thence', 'which', 'genuine', 'show', 'next', 'mine', 'well', 'nowhere', 'your', 'both', 'into', 'name', 'before', 'several', 'off', 'there', 'no', 'third', 'was', 'two', 'perhaps', 'against', 'n’t', 'if', 'may', 'from', '’m', 'everyone', 'any', 'already', 'whereafter', 'becoming', 'me', 'beforehand', 'onto', 'neither', 'the', 'part', 'formerly', 'anyway', 'whither', 'yours', 'through', 'work', 'namely', 'say', 'above', 'whereupon', 'always', 'elsewhere', 'although', 'anywhere', 'make', 'nobody', '’ll', 'some', 'everywhere', 'first', 'you', 'after', 'are', ' ', 'our', 'do', 'else', '‘d', 'only', 'various', 'however', 'rather', 'others', 'up', 'together', 'give', 'how', 'them', 'between', 'without', 'under', 'too', 'throughout', 'hereby', 're', 'due', 'ever', 'while', 'been', 'because', 'four', 'somewhere', 'when', '‘ve', 'whose', 'yourselves', 'three', 'few', 'myself', '‘m', 'seeming', 'see', 'twenty', 'eleven', 'amount', 'beyond', 'such', "'re", 'their', 'whoever', 'did', 'yourself', 'less', 'here', 'own', 'hence', 'alone', 'i', 'another', 'more', 'side', 'him', 'themselves', 'we', 'keep', 'during', 'twelve', 'much', 'upon', 'where', 'herein', 'many', 'whenever', 'indeed', 'fifteen', 'over', 'those', 'even', 'sometimes', ', ', 'move', 'most', 'ten', 'using', 'within', 'like', 'seems', 'since', 'an', ',', 'toward', 'moreover', 'become', 'beside', 'hers', 'somehow', 'get', 'last', 'wherein', 'now', 'good', 'out', 'not', 'amongst', 'put', 'via', 'nothing', 'hereafter', 'she', 'take', "'m", 'or', "'ve", 'am', 'herself', 'forty', 'of', 'on', 'each', 'he', 'often', '’ve', "n't", '1', 'once', 'none', 'should', 'ca', 'behind', 'at', 'becomes', 'thru', 'someone', 'must', 'my', 'towards', 'six', 'done', 'call', 'whence', 'bottom', 'besides', 'its', 'never', 'doing', 'being', 'latterly', 'front', 'that', 'it', '‘s', 'down', 'other', 'but', 'just', 'quite', 'wherever', 'place', 'thus', 'around', 'his', 'could', 'further', 'seem', 'might', 'would', '’d', 'made', 'enough', 'whereas', 'everything', 'nevertheless', 'were', 'among', 'love', 'what', 'latter', 'whole', 'therefore', 'itself', 'one', 'also', 'nor', 'by', 'this', 'all', 'cannot', 'hundred', 'used', 'whereby', 'for', 'across', 'sixty', 'least', 'whatever', 'coffee', 'fifty', 'has', 'a', 'top', 'per', 'then', 'who', 'about'}

# %%
# Use the get_lemmas function from lecture
def get_lemmas(text):
    lemmas = []
    nlp.Defaults.stop_words.union([' ', ',', ', ', 'coffee', 'place', 'good', 'like', 'work', 'shop', 'austin', '1',
                                            'get', 'love', 'genuine'])
    
    doc = nlp(text)
    
    for token in doc:
        if ((token.is_stop == False) and (token.is_punct == False)) and (token.pos!= 'PRON'):
            #if token.lemma_ == 'coffee':
             #   print(token.is_stop)
            lemmas.append(token.lemma_)
            
    return lemmas

# %%
# creating a tokens columns seperate from full_review_text for... tokens
# AND applying the get_lemmas function from lecture
df['tokens'] = df['full_review_text'].apply(get_lemmas)

# %%
df['tokens']
# Out:
# 5241    [seriously, good, ice, chai, austin, coffee, f...
# 5242    [room, nice, plain, coffee, meh, intriguing, m...
# 5243    [1, check, artist, group, belong, planning, me...
# 5244    [1, check, come, high, rate, coffee, shop, nea...
# 5245    [hand, favorite, coffee, shop, austin, vibe, p...
# 5246    [1, check, nice, cozy, coffee, shop, somewhat,...
# 5247    [sunday, morning, breakfast, taco, breakfast, ...
# 5248    [list, coffee, shop, work, like, atmosphere, p...
# 5249    [1, check, eh, find, randomly, try, find, plac...
# 5250    [4, check, in, good, love, ppl, work, love, dr...
# 5251    [have, recent, need, thinkin, tea, drinkin, jo...
# 5252    [way, lay, coffee, shop, subversive, edge, rec...
# 5253    [love, place, time, visit, family, austin, hit...
# 5254    [2, check, in, absolutely, love, authentic, au...
# 5255    [wife, come, like, decor, ambiance, coffee, go...
# 5256    [bit, time, morning, work, look, great, place,...
# 5257    [1, check, huge, fan, grungy, hipster, coffee,...
# 5258    [sit, gj, right, drink, bad, americano, life, ...
# 5259    [pretty, neat, little, place, hole, wall, vibe...
# 5260    [like, coffee, shop, make, feel, right, home, ...
# 5261    [get, way, mocha, keep, rave, choke, half, giv...
# 5262    [coffeeshop, good, outstanding, decent, servic...
# 5263    [12, check, in, list, thank, latte, place, win...
# 5264    [list, austin, cafe, coffee, vs, community, sp...
# 5265    [2, check, in, great, little, austin, coffee, ...
# 5266    [love, cafe, great, ice, coffee, atmosphere, c...
# 5267    [enjoy, coffee, year, good, coffee, great, peo...
# 5268    [1, check, list, austin, great, place, lazy, c...
# 5269    [love, atmosphere, perfect, work, plenty, comf...
# 5270    [3, 4, star, meet, space, coffee, food, barely...
#                               ...
# 5311    [1, check, great, atmosphere, coffee, taco, co...
# 5312    [613, check, in, great, little, neighborhood, ...
# 5313    [1, check, place, lot, charm, character, absol...
# 5314    [2, check, in, love, place, remind, true, aust...
# 5315    [4, check, in, place, feel, like, belong, stre...
# 5316    [7, check, in, quintessential, uber, local, co...
# 5317    [1, check, walk, think, place, quiet, realize,...
# 5318    [great, place, sit, open, air, deck, morning, ...
# 5319    [love, place, make, think, people, remember, a...
# 5320    [great, experience, quirky, relaxing, spot, or...
# 5321    [1, check, ok, totally, austin, vibe, great, j...
# 5322    [1, check, come, couple, year, sure, adore, fo...
# 5323    [perfect, place, homework, hang, environment, ...
# 5324    [1, check, love, genuine, joe, meet, north, us...
# 5325    [come, genuine, joe, year, bad, experience, qu...
# 5326    [4, check, in, genuine, joe, small, neighborho...
# 5327    [3, check, in, list, caffeine, boost, burnet, ...
# 5328    [love, place, coffee, good, people, fast, frie...
# 5329    [start, coffee, star, atmosphere, couple, star...
# 5330    [3, check, in, fact, place, crowd, weekday, te...
# 5331    [good, friendly, service, get, place, 2, star,...
# 5332    [2, check, in, like, stop, short, meet, n, gre...
# 5333    [nice, place, coffee, average, like, coffee, a...
# 5334    [write, review, time, will, go, gj, tonight, g...
# 5335    [1, check, pleasure, quickly, stop, minute, ki...
# 5336    [1, check, spot, great, find, thank, yelp, cha...
# 5337    [decent, coffee, nice, people, understaffed, f...
# 5338    [10, check, in, love, vibe, remind, hawaii, pa...
# 5339    [3, check, in, anderson, fairly, large, road, ...
# 5340    [good, way, describe, place, try, hard, try, t...
# Name: tokens, Length: 100, dtype: object

# %%
# Creating the count function from lecture, and creating the word count Dataframe 
from collections import Counter

def count(docs):

        word_counts = Counter()
        appears_in = Counter()
        
        total_docs = len(docs)

        for doc in docs:
            word_counts.update(doc)
            appears_in.update(set(doc))

        temp = zip(word_counts.keys(), word_counts.values())
        
        wc = pd.DataFrame(temp, columns = ['word', 'count'])

        wc['rank'] = wc['count'].rank(method='first', ascending=False)
        total = wc['count'].sum()

        wc['pct_total'] = wc['count'].apply(lambda x: x / total)
        
        wc = wc.sort_values(by='rank')
        wc['cul_pct_total'] = wc['pct_total'].cumsum()

        t2 = zip(appears_in.keys(), appears_in.values())
        ac = pd.DataFrame(t2, columns=['word', 'appears_in'])
        wc = ac.merge(wc, on='word')

        wc['appears_in_pct'] = wc['appears_in'].apply(lambda x: x / total_docs)
        
        return wc.sort_values(by='rank')

# %%
wc = count(df['tokens'])
wc.head(40)
# Out:
#          word  appears_in  count  rank  pct_total  cul_pct_total  \
# 22     coffee          78    142   1.0   0.032931       0.032931
# 29      place          54     78   2.0   0.018089       0.051020
# 25       good          48     65   3.0   0.015074       0.066095
# 57       like          36     54   4.0   0.012523       0.078618
# 35       work          35     49   5.0   0.011364       0.089981
# 81       room          27     45   6.0   0.010436       0.100417
# 112      shop          34     45   7.0   0.010436       0.110853
# 93      check          42     43   8.0   0.009972       0.120826
# 8       great          35     39   9.0   0.009045       0.129870
# 19     austin          31     38  10.0   0.008813       0.138683
# 60        joe          25     31  11.0   0.007189       0.145872
# 54       nice          25     30  12.0   0.006957       0.152829
# 166     drink          19     30  13.0   0.006957       0.159787
# 168      come          21     29  14.0   0.006725       0.166512
# 18       chai          16     28  15.0   0.006494       0.173006
# 108      time          23     28  16.0   0.006494       0.179499
# 266      love          25     28  17.0   0.006494       0.185993
# 5      people          23     27  18.0   0.006262       0.192254
# 72        get          21     26  19.0   0.006030       0.198284
# 213  friendly          24     25  20.0   0.005798       0.204082
# 89    genuine          18     24  21.0   0.005566       0.209647
# 102         1          22     23  22.0   0.005334       0.214981
# 117   meeting          16     23  23.0   0.005334       0.220315
# 122      cool          18     23  24.0   0.005334       0.225649
# 24        tea          11     22  25.0   0.005102       0.230751
# 110     latte          15     22  26.0   0.005102       0.235853
# 245       try          15     21  27.0   0.004870       0.240724
# 242      find          16     20  28.0   0.004638       0.245362
# 126    pretty          15     19  29.0   0.004406       0.249768
# 412        go          16     19  30.0   0.004406       0.254174
# 531      feel          12     19  31.0   0.004406       0.258581
# 96    parking          17     18  32.0   0.004174       0.262755
# 204     staff          17     18  33.0   0.004174       0.266929
# 268        in          18     18  34.0   0.004174       0.271104
# 373       day          14     18  35.0   0.004174       0.275278
# 404       way          13     18  36.0   0.004174       0.279453
# 95       vibe          16     17  37.0   0.003942       0.283395
# 170      area          13     17  38.0   0.003942       0.287338
# 30      house          12     16  39.0   0.003711       0.291048
# 192   seating          16     16  40.0   0.003711       0.294759
#
#      appears_in_pct
# 22             0.78
# 29             0.54
# 25             0.48
# 57             0.36
# 35             0.35
# 81             0.27
# 112            0.34
# 93             0.42
# 8              0.35
# 19             0.31
# 60             0.25
# 54             0.25
# 166            0.19
# 168            0.21
# 18             0.16
# 108            0.23
# 266            0.25
# 5              0.23
# 72             0.21
# 213            0.24
# 89             0.18
# 102            0.22
# 117            0.16
# 122            0.18
# 24             0.11
# 110            0.15
# 245            0.15
# 242            0.16
# 126            0.15
# 412            0.16
# 531            0.12
# 96             0.17
# 204            0.17
# 268            0.18
# 373            0.14
# 404            0.13
# 95             0.16
# 170            0.13
# 30             0.12
# 192            0.16

# %%
# Now for analysis of coffee shops overall
df['rating'].value_counts()
# Out:
# 5.0    40
# 4.0    35
# 3.0    11
# 2.0     8
# 1.0     6
# Name: rating, dtype: int64

# %%
import seaborn as sns
sns.distplot(df['rating'])

# %%
# examining the Language used in two seperate dataframes, one for good(4 star ratings or higher), and bad(lower than 4 star )
wc_bad = count(df[df['rating'] < 4]['tokens'])
wc_good= count(df[df['rating'] >= 4]['tokens'])

# %%
# Barplots for Good
sns.barplot(x='count', y='word', data = wc_good[wc_good['count'] > 15])
plt.figure(figsize=(16, 6))

# %%
# Bar chart for Bad
sns.barplot(x='count', y='word', data = wc_bad[wc_bad['count'] > 5])
plt.figure(figsize=(16, 6))

# %%
# Squarify plot for Good Reviews
import squarify
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure


wcgood_square = wc_good[wc_good['count'] > 15]
squarify.plot(sizes=wcgood_square['pct_total'], label=wcgood_square['word'], alpha=.8)
fig_size = plt.rcParams["figure.figsize"]
plt.axis('off')
fig_size[0] = 18
fig_size[1] = 18
plt.show()

# %%
# Squarify Plot for Bad Reviews

wcgood_square = wc_bad[wc_bad['count'] > 5]
squarify.plot(sizes=wcgood_square['pct_total'], label=wcgood_square['word'], alpha=.8)
fig_size = plt.rcParams["figure.figsize"]
plt.axis('off')
fig_size[0] = 18
fig_size[1] = 18
plt.show()
